# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('housing.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
df.sample(3)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 1581      48855.851354             7.723275                   8.391225
# 1736      75675.165905             4.907284                   6.908682
# 2841      61088.393614             5.810725                   6.085444
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 1581                          5.12     49890.508275  1.471828e+06
# 1736                          3.40     45103.571641  1.388783e+06
# 2841                          2.18     40426.835168  1.019881e+06
#
#                                                 Address
# 1581             584 Walker Harbor\nSmithfort, NY 92619
# 1736  58890 Mack Hollow Suite 313\nAlvarezside, WI 5...
# 2841  9649 Caitlyn Meadows Suite 390\nMcdowellside, ...

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# min                        2.000000       172.610686  1.593866e+04
# 25%                        3.140000     29403.928702  9.975771e+05
# 50%                        4.050000     36199.406689  1.232669e+06
# 75%                        4.490000     42861.290769  1.471210e+06
# max                        6.500000     69621.713378  2.469066e+06

# %%
df['Address'].nunique()
# Out:
# 5000

# %%
df['Price'].nunique()
# Out:
# 5000

# %%
sns.pairplot(data=df ,kind='reg')

# %%
sns.heatmap(df.corr() , annot= True)
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
target = df['Price'] 
features = df[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms','Area Population']]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(
    features, target,test_size= 0.25, random_state= 101
)

# %%
xtrain.shape
# Out:
# (3750, 4)

# %%
xtest.shape
# Out:
# (1250, 4)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
model.score(xtest , ytest) *100
# Out:
# 91.70576659270534

# %%
ypred_test =  model.predict(xtest)
plt.scatter(ytest, ypred_test)
plt.grid()

# %%
xtrain.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Area Population'],
#       dtype='object')

# %%
query_data = {'Avg. Area Income': [200000], 'Avg. Area House Age':[6] , 'Avg. Area Number of Rooms':[5],'Area Population': [30000] }
result = model.predict(pd.DataFrame(query_data ))
print(result[0])
# Out:
# 3743363.8242754405

# %%
pd.to_pickle(model, 'housePrice.pickle')
